# %% [markdown]
# # Project Proposal
#
# This notebook gives you a template for your project proposal. Please refer to the [proposal specifications](https://middcs.github.io/csci-1010-w26/project.html#project-proposal) to guide your proposal writing.
#
# ## 1. Team Members
#
# *[TODO: Your response here]*
#
# ## 2. Abstract
#
# *[TODO: Your response here]*
#
# ## 3. Motivation
#
# *[TODO: Your response here]*
#
# ## 4. Planned Deliverables
#
# *[TODO: Your response here]*
#
# ## 5. Resources Required
#
# *[TODO: Your response here]*
#
# ## 6. What Skills You’ll Demonstrate
#
# *[TODO: Your response here]*
#
# ## 7. Risk Statement
#
# *[TODO: Your response here]*
#
# ## 8. Ethics Statement
#
# *[TODO: Your response here]*
#
# ## 9. Tentative Timeline
#
# *[TODO: Your response here]*
