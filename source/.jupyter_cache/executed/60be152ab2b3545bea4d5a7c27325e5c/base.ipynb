# %%
# imports
import os
import sys
import types
import json

# figure size/format
fig_width = 7
fig_height = 5
fig_format = 'retina'
fig_dpi = 96

# matplotlib defaults / format
try:
  import matplotlib.pyplot as plt
  plt.rcParams['figure.figsize'] = (fig_width, fig_height)
  plt.rcParams['figure.dpi'] = fig_dpi
  plt.rcParams['savefig.dpi'] = fig_dpi
  from IPython.display import set_matplotlib_formats
  set_matplotlib_formats(fig_format)
except Exception:
  pass

# plotly use connected mode
try:
  import plotly.io as pio
  pio.renderers.default = "notebook_connected"
except Exception:
  pass

# enable pandas latex repr when targeting pdfs
try:
  import pandas as pd
  if fig_format == 'pdf':
    pd.set_option('display.latex.repr', True)
except Exception:
  pass



# output kernel dependencies
kernel_deps = dict()
for module in list(sys.modules.values()):
  # Some modules play games with sys.modules (e.g. email/__init__.py
  # in the standard library), and occasionally this can cause strange
  # failures in getattr.  Just ignore anything that's not an ordinary
  # module.
  if not isinstance(module, types.ModuleType):
    continue
  path = getattr(module, "__file__", None)
  if not path:
    continue
  if path.endswith(".pyc") or path.endswith(".pyo"):
    path = path[:-1]
  if not os.path.exists(path):
    continue
  kernel_deps[path] = os.stat(path).st_mtime
print(json.dumps(kernel_deps))

# set run_path if requested
if r'/Users/philchodrow/Documents/teaching/ml-notes/source':
  os.chdir(r'/Users/philchodrow/Documents/teaching/ml-notes/source')

# reset state
# %reset

def ojs_define(**kwargs):
  import json
  try:
    # IPython 7.14 preferred import
    from IPython.display import display, HTML
  except:
    from IPython.core.display import display, HTML

  # do some minor magic for convenience when handling pandas
  # dataframes
  def convert(v):
    try:
      import pandas as pd
    except ModuleNotFoundError: # don't do the magic when pandas is not available
      return v
    if type(v) == pd.Series:
      v = pd.DataFrame(v)
    if type(v) == pd.DataFrame:
      j = json.loads(v.T.to_json(orient='split'))
      return dict((k,v) for (k,v) in zip(j["index"], j["data"]))
    else:
      return v
  
  v = dict(contents=list(dict(name=key, value=convert(value)) for (key, value) in kwargs.items()))
  display(HTML('<script type="ojs-define">' + json.dumps(v) + '</script>'), metadata=dict(ojs_define = True))
globals()["ojs_define"] = ojs_define
# Out:
# {"/Users/philchodrow/opt/anaconda3/envs/ml-0451/lib/python3.9/importlib/_bootstrap.py": 1669300367.0, "/Users/philchodrow/opt/anaconda3/envs/ml-0451/lib/python3.9/importlib/_bootstrap_external.py": 1669300367.0, "/Users/philchodrow/opt/anaconda3/envs/ml-0451/lib/python3.9/codecs.py": 1669300365.0, "/Users/philchodrow/opt/anaconda3/envs/ml-0451/lib/python3.9/encodings/aliases.py": 1669300368.0, "/Users/philchodrow/opt/anaconda3/envs/ml-0451/lib/python3.9/encodings/__init__.py": 1669300368.0, "/Users/philchodrow/opt/anaconda3/envs/ml-0451/lib/python3.9/encodings/utf_8.py": 1669300368.0, "/Users/philchodrow/opt/anaconda3/envs/ml-0451/lib/python3.9/encodings/latin_1.py": 1669300368.0, "/Users/philchodrow/opt/anaconda3/envs/ml-0451/lib/python3.9/abc.py": 1669300365.0, "/Users/philchodrow/opt/anaconda3/envs/ml-0451/lib/python3.9/io.py": 1669300365.0, "/Users/philchodrow/opt/anaconda3/envs/ml-0451/lib/python3.9/stat.py": 1669300365.0, "/Users/philchodrow/opt/anaconda3/envs/ml-0451/lib/python3.9/_collections_abc.py": 1669300365.0, "/Users/philchodrow/opt/anaconda3/envs/ml-0451/lib/python3.9/genericpath.py": 1669300365.0, "/Users/philchodrow/opt/anaconda3/envs/ml-0451/lib/python3.9/posixpath.py": 1669300365.0, "/Users/philchodrow/opt/anaconda3/envs/ml-0451/lib/python3.9/os.py": 1669300365.0, "/Users/philchodrow/opt/anaconda3/envs/ml-0451/lib/python3.9/_sitebuiltins.py": 1669300365.0, "/Users/philchodrow/opt/anaconda3/envs/ml-0451/lib/python3.9/_bootlocale.py": 1669300365.0, "/Users/philchodrow/opt/anaconda3/envs/ml-0451/lib/python3.9/site-packages/_distutils_hack/__init__.py": 1669270133.0, "/Users/philchodrow/opt/anaconda3/envs/ml-0451/lib/python3.9/types.py": 1669300365.0, "/Users/philchodrow/opt/anaconda3/envs/ml-0451/lib/python3.9/warnings.py": 1669300365.0, "/Users/philchodrow/opt/anaconda3/envs/ml-0451/lib/python3.9/importlib/__init__.py": 1669300367.0, "/Users/philchodrow/opt/anaconda3/envs/ml-0451/lib/python3.9/importlib/machinery.py": 1669300367.0, "/Users/philchodrow/opt/anaconda3/envs/ml-0451/lib/python3.9/lib-dynload/_heapq.cpython-39-darwin.so": 1669300396.0, "/Users/philchodrow/opt/anaconda3/envs/ml-0451/lib/python3.9/heapq.py": 1669300365.0, "/Users/philchodrow/opt/anaconda3/envs/ml-0451/lib/python3.9/keyword.py": 1669300365.0, "/Users/philchodrow/opt/anaconda3/envs/ml-0451/lib/python3.9/operator.py": 1669300365.0, "/Users/philchodrow/opt/anaconda3/envs/ml-0451/lib/python3.9/reprlib.py": 1669300365.0, "/Users/philchodrow/opt/anaconda3/envs/ml-0451/lib/python3.9/collections/__init__.py": 1669300368.0, "/Users/philchodrow/opt/anaconda3/envs/ml-0451/lib/python3.9/collections/abc.py": 1669300368.0, "/Users/philchodrow/opt/anaconda3/envs/ml-0451/lib/python3.9/functools.py": 1669300365.0, "/Users/philchodrow/opt/anaconda3/envs/ml-0451/lib/python3.9/contextlib.py": 1669300365.0, "/Users/philchodrow/opt/anaconda3/envs/ml-0451/lib/python3.9/enum.py": 1669300365.0, "/Users/philchodrow/opt/anaconda3/envs/ml-0451/lib/python3.9/sre_constants.py": 1669300365.0, "/Users/philchodrow/opt/anaconda3/envs/ml-0451/lib/python3.9/sre_parse.py": 1669300365.0, "/Users/philchodrow/opt/anaconda3/envs/ml-0451/lib/python3.9/sre_compile.py": 1669300365.0, "/Users/philchodrow/opt/anaconda3/envs/ml-0451/lib/python3.9/copyreg.py": 1669300365.0, "/Users/philchodrow/opt/anaconda3/envs/ml-0451/lib/python3.9/re.py": 1669300365.0, "/Users/philchodrow/opt/anaconda3/envs/ml-0451/lib/python3.9/typing.py": 1669300365.0, "/Users/philchodrow/opt/anaconda3/envs/ml-0451/lib/python3.9/importlib/abc.py": 1669300367.0, "/Users/philchodrow/opt/anaconda3/envs/ml-0451/lib/python3.9/importlib/util.py": 1669300367.0, "/Users/philchodrow/opt/anaconda3/envs/ml-0451/lib/python3.9/site.py": 1669300365.0, "/Users/philchodrow/opt/anaconda3/envs/ml-0451/lib/python3.9/_weakrefset.py": 1669300365.0, "/Users/philchodrow/opt/anaconda3/envs/ml-0451/lib/python3.9/weakref.py": 1669300365.0, "/Users/philchodrow/opt/anaconda3/envs/ml-0451/lib/python3.9/pkgutil.py": 1669300365.0, "/Users/ph ...
# /var/folders/xn/wvbwvw0d6dx46h9_2bkrknnw0000gn/T/ipykernel_58569/949127318.py:20: DeprecationWarning:
#
# `set_matplotlib_formats` is deprecated since IPython 7.23, directly use `matplotlib_inline.backend_inline.set_matplotlib_formats()`

# %%
#| fig-cap: '200 data points in the 2d plane, each of which has one of two labels.'
#| fig-cap-location: margin
#| label: fig-scatter

import numpy as np
from matplotlib import pyplot as plt
# from hidden.perceptron import perceptron_update, draw_line

def perceptron_data(n_points = 300, noise = 0.2):

    noise = 0.2
    n_points = 300

    y = np.arange(n_points) >= int(n_points/2)

    X = y[:, None] + np.random.normal(0.0, noise, size = (n_points,2))

    return X, y

perceptron_data()

#     for i in range(2):
#         x0 = i + np.random.normal(0.0, noise, size = n_points)
#         x1 = i + np.random.normal(0.0, noise, size = n_points)

#         plt.scatter(x, x1, s = 20,  c = i*(np.zeros_like(x) + 1), facecolors = "none", edgecolors = "darkgrey", cmap = "BrBG", label = f"Category {i+1}", vmin = -1, vmax = 2)

# np.random.seed(123)

# plt.rcParams["figure.figsize"] = (4, 4)
# Out:
# (array([[ 0.22234035,  0.03619143],
#         [ 0.26656019,  0.19778506],
#         [-0.1233941 , -0.23737734],
#         [ 0.08253392, -0.12650138],
#         [ 0.07533783, -0.14623039],
#         [-0.17224505, -0.02819816],
#         [ 0.18682012,  0.06130798],
#         [ 0.23567503, -0.24671234],
#         [-0.21141543, -0.01783274],
#         [ 0.43314028,  0.13485722],
#         [-0.21332255, -0.01522809],
#         [ 0.04414296, -0.11373715],
#         [ 0.122655  , -0.03128923],
#         [-0.05986614,  0.25205136],
#         [-0.34193218, -0.19236107],
#         [-0.1634618 , -0.16953621],
#         [-0.14575061,  0.09769519],
#         [ 0.21930657,  0.18320825],
#         [-0.20391243, -0.02148358],
#         [ 0.09045304,  0.04800059],
#         [ 0.26114948, -0.13506685],
#         [ 0.03126388, -0.07864614],
#         [ 0.050215  , -0.21577938],
#         [-0.18578754, -0.14602217],
#         [-0.11273386,  0.30958465],
#         [ 0.23508038, -0.04252993],
#         [ 0.03458666, -0.3188872 ],
#         [-0.03585847,  0.03192294],
#         [ 0.22913684,  0.06536094],
#         [ 0.08657801,  0.05955258],
#         [ 0.05380024, -0.27935184],
#         [-0.08335153,  0.28697736],
#         [ 0.16477929,  0.0988469 ],
#         [ 0.01334306,  0.13188828],
#         [-0.18897788, -0.31601191],
#         [-0.07641731,  0.10758461],
#         [ 0.02156598,  0.20279174],
#         [ 0.0702901 ,  0.00896844],
#         [ 0.26549699,  0.22647516],
#         [-0.01961826, -0.22060997],
#         [-0.1814723 , -0.03229023],
#         [-0.07336228,  0.33155247],
#         [-0.33602683, -0.01285156],
#         [-0.2132453 ,  0.02336037],
#         [ 0.07645297, -0.08097939],
#         [ 0.10609628, -0.03972539],
#         [-0.03587912, -0.08357775],
#         [ 0.13016486,  0.02770029],
#         [ 0.31464793,  0.25400498],
#         [ 0.11075492, -0.43188833],
#         [-0.29686566,  0.19725011],
#         [-0.09512771,  0.04696875],
#         [-0.12609508,  0.10357733],
#         [ 0.19159799, -0.24192555],
#         [-0.16271429, -0.33274568],
#         [ 0.04668146, -0.33305608],
#         [-0.07321634,  0.10392223],
#         [ 0.41161859,  0.07368367],
#         [ 0.25057695,  0.05183177],
#         [ 0.06184868, -0.04218458],
#         [-0.07665403,  0.23487563],
#         [ 0.07493487,  0.06725927],
#         [-0.12163505, -0.06900835],
#         [ 0.4134981 , -0.01350037],
#         [ 0.26523361, -0.10405034],
#         [ 0.16030883,  0.05795912],
#         [-0.08074262,  0.12971258],
#         [-0.30868878,  0.11492429],
#         [ 0.15738064,  0.05461464],
#         [ 0.26218474, -0.01362009],
#         [-0.02982784,  0.07100791],
#         [ 0.17354125,  0.1139681 ],
#         [-0.04532261, -0.19904557],
#         [ 0.13269585, -0.15791425],
#         [-0.16365507, -0.13092864],
#         [ 0.01154176, -0.15925929],
#         [-0.22713761, -0.13176839],
#         [-0.03666636,  0.09085689],
#         [ 0.01345338, -0.21609242],
#         [ 0.04573243,  0.0645511 ],
#         [-0.09099264, -0.15924921],
#         [-0.15932603, -0.10636246],
#         [ 0.44284841, -0.17781448],
#         [ 0.05319983, -0.14282052],
#         [-0.10119662, -0.14122729],
#         [ 0.16024048,  0.07582157],
#         [-0.02586876,  0.10058699],
#         [ 0.14869314, -0.17014301],
#         [ 0.10945048, -0.14352634],
#         [ 0.16758705,  0.1480397 ],
#         [ 0.08074061, -0.04198527],
#         [-0.10522185, -0.05272574],
#         [ 0.15383095, -0.13646621],
#         [ 0.00993425, -0.34952583],
#         [ 0.05207493, -0.20710568],
#         [-0.26362735,  0.10374298],
#         [ 0.04206751, -0.0886755 ],
#         [-0.06041914,  0.45420675],
#         [-0.03882886, -0.04024321],
#         [ 0.13046106,  0.01744247],
#         [ 0.19748569,  0.05548976],
#         [ 0.15221783,  0.08866608],
#         [ 0.12906075, -0.00853059],
#         [ 0.04450556, -0.0542071 ],
#         [ 0.1208339 , -0.26920774],
#         [ 0.14522726,  0.19960507],
#         [ 0.14835236, -0.02081954],
#         [ 0.10104584, -0.15531573],
#         [ 0.16742044, -0.21984306],
#         [ 0.11874622,  0.10653148],
#         [ 0.08134557, -0.08941673],
#         [ 0.15203325, -0.36745297],
#         [ 0.15544436,  0.03828758],
#         [ 0.21019173,  0.0400098 ],
#         [ 0.36763803, -0.18836387],
#         [ 0.12188146, -0.1772009 ],
#         [-0.02527724,  0.14847452],
#         [ 0.12508607,  0.41590774],
#         [-0.07028135,  0.25720027],
#         [-0.05086004, -0.14018002],
#         [-0.32459071,  0.03253413],
#         [-0.10426112,  0.16950347],
#         [-0.10568015, -0.09532031],
#         [ 0.07093106,  0.34424316],
#         [-0.21772998,  0.20352256],
#         [ 0.17482106, -0.04418919],
#         [ 0.13508326, -0.05685529],
#         [ 0.47427769, -0.02241906],
#         [ 0.01608282, -0.06515832],
#         [-0.33869081, -0.05263068],
#         [ 0.04640739,  0.30018452],
#         [ 0.09839143, -0.03787644],
#         [ 0.01198864,  0.06546807],
#         [-0.07579321,  0.1364474 ],
#         [ 0.32501763, -0.07262975],
#         [ 0.24150605,  0.17526526],
#         [ 0.10744897,  0.02238512],
#         [ 0.06755677, -0.04347863],
#         [ 0.3673737 , -0.14368063],
#         [ 0.22698894,  0.30994434],
#         [-0.06462687,  0.23316939],
#         [ 0.02879627,  0.01247196],
#         [-0.01491274, -0.32274622],
#         [ 0.10958479,  0.28871035],
#         [-0.14094408,  0.16946773],
#         [-0.01704108, -0.21853785],
#         [ 0.19957799,  0.33720737],
#         [-0.15885047,  0.04316034],
#         [-0.28794714, -0.00840146],
#         [ 0.09721328,  0.35058192],
#         [ 1.31151474,  1.32849967],
#         [ 0.89458161,  0.95096699],
#         [ 0.66713892,  0.8569689 ],
#         [ 0.70963416,  1.07310738],
#         [ 0.860602  ,  0.77971555],
#         [ 0.92891711,  0.76302461],
#         [ 1.06180336,  1.0568895 ],
#         [ 0.93685748,  0.8538649 ],
#         [ 0.73211173,  1.11107132],
#         [ 1.04574415,  1.09286309],
#         [ 0.93871292,  0.9564153 ],
#         [ 1.28839983,  0.87988303],
#         [ 0.9374712 ,  1.14877842],
#         [ 1.06058226,  0.59067556],
#         [ 0.66242265,  0.86783375],
#         [ 1.18205993,  1.13433462],
#         [ 1.10390467,  1.12554882],
#         [ 0.80621105,  1.12020942],
#         [ 0.81574326,  1.18945984],
#         [ 0.89788697,  1.05632522],
#         [ 0.62510032,  0.73022222],
#         [ 1.21813549,  1.13834877],
#         [ 0.75641265,  1.25711834],
#         [ 0.78184311,  1.00399222],
#         [ 0.90397988,  0.81531696],
#         [ 1.23358811,  1.3369963 ],
#         [ 1.03565484,  1.30519978],
#         [ 0.94375699,  1.02166172],
#         [ 1.02629785,  0.76865822],
#         [ 1.09989138,  1.14193863],
#         [ 0.96530527,  0.66164977],
#         [ 1.0735411 ,  0.6969973 ],
#         [ 0.83774603,  1.02628426],
#         [ 0.84606751,  1.05073533],
#         [ 0.95475795,  0.6739007 ],
#         [ 1.03359431,  1.11731594],
#         [ 1.20248005,  0.92668639],
#         [ 0.98770326,  0.70097827],
#         [ 1.39297788,  1.30100164],
#         [ 0.9936332 ,  0.97503165],
#         [ 0.41395543,  1.20705251],
#         [ 1.11257224,  1.16256237],
#         [ 0.91895037,  0.90611423],
#         [ 0.75291627,  1.15560195],
#         [ 1.25043078,  1.22477658],
#         [ 1.03745152,  0.93466966],
#         [ 0.78960592,  0.8596499 ],
#         [ 1.09351009,  0.94308932],
#         [ 1.32828084,  1.23047121],
#         [ 0.87963817,  0.75686759],
#         [ 0.89031633,  1.21307659],
#         [ 0.89521552,  1.1091976 ],
#         [ 0.88682398,  1.06863283],
#         [ 1.10562839,  1.19716665],
#         [ 1.28664803,  1.26204579],
#         [ 0.8939657 ,  0.97059625],
#         [ 0.76529498,  0.95286294],
#         [ 1.00486343,  0.91920801],
#         [ 0.89928309,  1.20641604],
#         [ 1.18149659,  1.07982441],
#         [ 0.74449788,  1.04018618],
#         [ 0.92315369,  1.26314549],
#         [ 0.63954185,  0.88823526],
#         [ 0.88266994,  0.90668519],
#         [ 1.19151575,  0.52952832],
#         [ 0.95838956,  1.17014413],
#         [ 1.1960235 ,  0.89018443],
#         [ 0.86404437,  1.06924271],
#         [ 1.03020734,  1.01388062],
#         [ 0.23972436,  0.77456556],
#         [ 0.82735539,  1.12860197],
#         [ 0.71184806,  0.79067449],
#         [ 0.9691232 ,  0.74248096],
#         [ 1.12857078,  0.92171926],
#         [ 1.36658119,  0.87405626],
#         [ 0.88474336,  1.16088766],
#         [ 0.86893261,  1.30231366],
#         [ 1.09658299,  0.93922401],
#         [ 0.9678404 ,  1.57014155],
#         [ 1.09773087,  1.0300954 ],
#         [ 0.97348465,  1.20743241],
#         [ 0.69633474,  0.9637624 ],
#         [ 0.43326851,  0.89331847],
#         [ 1.16958536,  1.27644617],
#         [ 1.12119405,  1.12799372],
#         [ 0.6568197 ,  0.86432524],
#         [ 1.294881  ,  0.895228  ],
#         [ 0.97280352,  0.8388876 ],
#         [ 0.8132497 ,  0.90594615],
#         [ 0.86778881,  1.19150036],
#         [ 1.04307392,  1.20377677],
#         [ 0.7225525 ,  1.24509063],
#         [ 1.00429124,  1.36786968],
#         [ 0.98944477,  0.70131964],
#         [ 1.25684413,  0.97270235],
#         [ 0.56957698,  1.02903894],
#         [ 1.04624563,  1.21522255],
#         [ 0.28250123,  1.2297739 ],
#         [ 0.90508065,  1.38524958],
#         [ 0.6563438 ,  1.10906778],
#         [ 1.08234377,  0.91557705],
#         [ 0.84523882,  0.92525099],
#         [ 0.93065594,  0.7493124 ],
#         [ 1.19859843,  0.78155993],
#         [ 1.2046382 ,  0.64221309],
#         [ 0.96456204,  0.96753869],
#         [ 0.99684113,  1.19125918],
#         [ 0.95953056,  0.90841412],
#         [ 0.96013448,  1.19620137],
#         [ 0.75887861,  0.7958663 ],
#         [ 0.60866035,  1.40544974],
#         [ 0.76805105,  0.62291367],
#         [ 0.83822017,  0.87750895],
#         [ 1.2930912 ,  0.90702015],
#         [ 1.05835386,  0.64184404],
#         [ 1.0415967 ,  0.67024075],
#         [ 0.93728099,  0.8480258 ],
#         [ 1.0116543 ,  1.12688174],
#         [ 0.73282081,  0.77271631],
#         [ 1.0387178 ,  1.13745714],
#         [ 1.28347504,  0.90562165],
#         [ 0.70170427,  1.03732514],
#         [ 0.84107126,  0.81511596],
#         [ 1.28163541,  1.12374336],
#         [ 0.85438443,  0.99625769],
#         [ 0.9828646 ,  1.03301912],
#         [ 0.91881208,  0.61998749],
#         [ 0.80472996,  0.89360068],
#         [ 1.00562235,  0.78354113],
#         [ 1.03725699,  0.92374571],
#         [ 0.84810498,  0.74594478],
#         [ 1.08929828,  1.08484868],
#         [ 1.16004418,  1.10985765],
#         [ 1.12482689,  1.07641572],
#         [ 0.64831806,  0.94417622],
#         [ 0.71352351,  1.27384242],
#         [ 0.99719726,  1.25395117],
#         [ 0.79393554,  0.98162616],
#         [ 1.05267485,  0.93381957],
#         [ 1.03755788,  1.29643269],
#         [ 0.79361732,  0.4724155 ],
#         [ 1.32012483,  0.84166755],
#         [ 1.22449994,  1.13038266],
#         [ 0.95666264,  1.07606896],
#         [ 0.77189315,  1.01717943],
#         [ 1.11880804,  0.84513345],
#         [ 0.92394178,  1.0625187 ],
#         [ 1.26465474,  0.99936903],
#         [ 0.91386803,  0.97071685],
#         [ 1.23203519,  0.87169753]]),
#  array([False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True]))
